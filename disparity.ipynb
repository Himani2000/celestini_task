# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import cv2

# %%
left_image='img0.png'
right_image='img1.png'

# %%
left=cv2.imread('im0.png')
right=cv2.imread('im1.png')

# %%
type(left),type(right)
left.shape,right.shape
# Out:
# ((496, 718, 3), (496, 718, 3))

# %%
plt.imshow(left)
#plt.imshow(right)
#plt.show()

# %%
plt.imshow(right)

# %%
### image disparity code 

### file  path code 
import os
filename='trainingQ'
path = 'images'


for (curdir, subsHere, filesHere) in os.walk(filename):
    for i,files in enumerate(filesHere):
        
        
        img=cv2.imread(os.path.join(curdir,files))
        cv2.imwrite(os.path.join(path ,'{}.png'.format(i)), img)

# %%
files = os.listdir(filename)

# %%
files
# Out:
# ['MotorcycleE',
#  'Playtable',
#  'Adirondack',
#  'Playroom',
#  'Piano',
#  'PlaytableP',
#  'PianoL',
#  'ArtL',
#  'Vintage',
#  'Pipes',
#  'Jadeplant',
#  'Shelves',
#  'Recycle',
#  'Motorcycle',
#  'Teddy']
